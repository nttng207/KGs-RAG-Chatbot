# %%
# !pip install llama_index
# !pip install transformers accelerate bitsandbytes
# !pip install pypdf
# !pip install neo4j
# !pip install ctransformers[cuda]>=0.2.24
# !pip install langchain

# %%
! wget https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q5_K_S.gguf
# Out:
# --2024-01-17 15:21:51--  https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q5_K_S.gguf
# Resolving huggingface.co (huggingface.co)... 18.172.134.88, 18.172.134.124, 18.172.134.4, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.88|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/72/62/726219e98582d16c24a66629a4dec1b0761b91c918e15dea2625b4293c134a92/83d1104865d0790ada7a5e1191f2f702b9956ff3a457d67109ded0ab6a56aafd?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27mistral-7b-instruct-v0.2.Q5_K_S.gguf%3B+filename%3D%22mistral-7b-instruct-v0.2.Q5_K_S.gguf%22%3B&Expires=1705762996&Policy=&Signature=IMyS5FFilg0JS1Qmn27QpnabSZeey1zNro3p6B%7E%7EzHQEMC6wYRUzvA9%7EBnpwktrjGOBs5Pq77qIGB8pNzdFdu9ncrtSLvP2739zL6Dsl%7ErrCi-GKayIeh-60yOTPpqmPKYRd63Ud2mOWAzQviOyw-GvOF0uAA29y0ySRhP3DQ45biOk52OHGUbx2jXOflteQpWtD6ctkbZ9Z0HCX7yAP0-hUW0vgfdf9QxrgZW3Xvbj%7EMkT1YgKE9s46iVwdL8cbJQHnHJBKNroA36mXfnT3WwGP0OPTAeXWro4FqBbCmhc%7EATAz8fCW81VvsBTiwWmt3d4sIq0A4Il3dezvmZ4Ibw__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-01-17 15:21:51--  https://cdn-lfs-us-1.huggingface.co/repos/72/62/726219e98582d16c24a66629a4dec1b0761b91c918e15dea2625b4293c134a92/83d1104865d0790ada7a5e1191f2f702b9956ff3a457d67109ded0ab6a56aafd?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27mistral-7b-instruct-v0.2.Q5_K_S.gguf%3B+filename%3D%22mistral-7b-instruct-v0.2.Q5_K_S.gguf%22%3B&Expires=1705762996&Policy=&Signature=IMyS5FFilg0JS1Qmn27QpnabSZeey1zNro3p6B%7E%7EzHQEMC6wYRUzvA9%7EBnpwktrjGOBs5Pq77qIGB8pNzdFdu9ncrtSLvP2739zL6Dsl%7ErrCi-GKayIeh-60yOTPpqmPKYRd63Ud2mOWAzQviOyw-GvOF0uAA29y0ySRhP3DQ45biOk52OHGUbx2jXOflteQpWtD6ctkbZ9Z0HCX7yAP0-hUW0vgfdf9QxrgZW3Xvbj%7EMkT1YgKE9s46iVwdL8cbJQHnHJBKNroA36mXfnT3WwGP0OPTAeXWro4FqBbCmhc%7EATAz8fCW81VvsBTiwWmt3d4sIq0A4Il3dezvmZ4Ibw__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 108.156.107.49, 108.156.107.44, 108.156.107.80, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|108.156.107.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4997716256 (4.7G) [binary/octet-stream]
# Saving to: ‘mistral-7b-instruct-v0.2.Q5_K_S.gguf’
#
# mistral-7b-instruct 100%[===================>]   4.65G   224MB/s    in 31s
#
# 2024-01-17 15:22:22 (155 MB/s) - ‘mistral-7b-instruct-v0.2.Q5_K_S.gguf’ saved [4997716256/4997716256]

# %%
from langchain_community.llms import CTransformers

config = {"gpu_layers": 30,
          "context_length": 5000}

llm = CTransformers(
        model = "TheBloke/Llama-2-7B-Chat-GGML",
        model_type="llama",
        temperature = 0.1,
        max_new_token = 2000,
        config = config
    )
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from llama_index.readers import BeautifulSoupWebReader
from llama_index import (
    SimpleDirectoryReader,
    GPTVectorStoreIndex,
    VectorStoreIndex,
    ServiceContext,
    download_loader,
    PromptHelper,
    StorageContext,
    load_index_from_storage,
    StorageContext,
    KnowledgeGraphIndex,
    load_graph_from_storage
)
from llama_index.llms import AzureOpenAI, OpenAI
from llama_index.query_engine import KnowledgeGraphQueryEngine
from llama_index.graph_stores import Neo4jGraphStore, NebulaGraphStore
from llama_index.embeddings import HuggingFaceEmbedding, OpenAIEmbedding, LangchainEmbedding
from llama_index.response.notebook_utils import display_response
from llama_index.graph_stores import SimpleGraphStore
from llama_index.vector_stores import ChromaVectorStore
from IPython.display import Markdown, display
import openai

# %%
os.environ["OPENAI_API_KEY"] = "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"

llm = OpenAI(
    temperature=0,
    model="gpt-3.5-turbo",
)

# %%
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python
from llama_index.llms import LlamaCPP

# %%
import torch
from transformers import BitsAndBytesConfig
from llama_index.prompts import PromptTemplate
from llama_index.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.llms import HuggingFaceLLM
from llama_index.llms.llama_utils import (
    messages_to_prompt,
    completion_to_prompt,
)
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
import logging
import sys
import os

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

llama_debug = LlamaDebugHandler(print_trace_on_end=True)
callback_manager = CallbackManager([llama_debug])
model_url = "https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q5_K_M.gguf"

# Change LLMs and see different !!!

llm = LlamaCPP(model_url=model_url, model_path=None,
    temperature=0.1,
    max_new_tokens=256,
    model_kwargs={"n_gpu_layers": 35},
    callback_manager = callback_manager,
    messages_to_prompt=messages_to_prompt,
    completion_to_prompt=completion_to_prompt,
    verbose = True)
# Out:
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
response = llm.complete("Do you know Manchester United?")
print(response.text)
# Out:
# ################################################################################################################################################################################################################################################################

# %%
from pathlib import Path
from llama_index import download_loader

PDFReader = download_loader("PDFReader")

loader = PDFReader()
documents = loader.load_data(file=Path('/content/Employment-Manual-January-2023-trang-1.pdf'))

# %%
prompt = """
<s><INST> ## 1. Overview
You are a top-tier algorithm designed for extracting information about a guide for employees who want to understand labor laws in structured formats to build a knowledge graph.
- **Nodes** represent entities and concepts. They're akin to Wikipedia nodes.
- The aim is to achieve simplicity and clarity in the knowledge graph, making it accessible for a vast audience.
## 2. Labeling Nodes
- **Consistency**: Ensure you use basic or elementary types for node labels.
  - For example, when you identify an entity representing a person, always label it as **"person"**. Avoid using more specific terms like "mathematician" or "scientist".
- **Node IDs**: Never utilize integers as node IDs. Node IDs should be names or human-readable identifiers found in the text.
## 3. Handling Numerical Data and Dates
- Numerical data, like age or other related information, should be incorporated as attributes or properties of the respective nodes.
- **No Separate Nodes for Dates/Numbers**: Do not create separate nodes for dates or numerical values. Always attach them as attributes or properties of nodes.
- **Property Format**: Properties must be in a key-value format.
- **Quotation Marks**: Never use escaped single or double quotes within property values.
- **Naming Convention**: Use camelCase for property keys, e.g., `birthDate`.
## 4. Coreference Resolution
- **Maintain Entity Consistency**: When extracting entities, it's vital to ensure consistency.
If an entity, such as "John Doe", is mentioned multiple times in the text but is referred to by different names or pronouns (e.g., "Joe", "he"),
always use the most complete identifier for that entity throughout the knowledge graph. In this example, use "John Doe" as the entity ID.
Remember, the knowledge graph should be coherent and easily understandable, so maintaining consistency in entity references is crucial.
## 5. Strict Compliance
Adhere to the rules strictly.Do not contain any explanations or appologies in your response.Non-compliance will result in termination.

Example:
 "Some text is provided below. Given the text, extract up to "
    "{max_knowledge_triplets} "
    "knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n"
    "---------------------\n"
    "Example:"
    "Text: Alice is Bob's mother."
    "Triplets:\n(Alice, is mother of, Bob)\n"
    "Text: Philz is a coffee shop founded in Berkeley in 1982.\n"
    "Triplets:\n"
    "(Philz, is, coffee shop)\n"
    "(Philz, founded in, Berkeley)\n"
    "(Philz, founded in, 1982)\n"
    "---------------------\n"
    "Text: {text}\n"
    "Triplets:\n"
 </INST>
"""
prompt_template = PromptTemplate(prompt, prompt_type = "knowledge_triplet_extract")

# %%
#embed_model = OpenAIEmbedding() #sentence-transformers/all-roberta-large-v1
embed_model = LangchainEmbedding(HuggingFaceEmbedding("sentence-transformers/all-roberta-large-v1")) #local:BAAI/bge-small-en-v1.5
service_context = ServiceContext.from_defaults(llm=llm, embed_model=embed_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/328 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
username = "neo4j"
password = "7q0G7tP_ZxJGK-HH87pNoLMqcCO4sDN2cQnPIASwzLw"
url = "neo4j+s://39992655.databases.neo4j.io"
database = "neo4j"

# %%
graph_store = Neo4jGraphStore(
    username=username,
    password=password,
    url=url,
    database=database,
)

storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %%
index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=10,
    #kg_triplet_extract_fn=extract_triplets,
    service_context=service_context,
    kg_triple_extract_template=prompt_template,
    #include_embedding = True,
    show_progress = True
)
# Out:
# Parsing nodes:   0%|          | 0/12 [00:00<?, ?it/s]
# Processing nodes:   0%|          | 0/262 [00:00<?, ?it/s]
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit

# %%
query_engine = index.as_query_engine(
    include_text=False,
    response_mode="tree_summarize", #test response !!!
    #embedding_mode="hybrid", #
    similarity_top_k=5,
    #explore_global_knowledge=True
)

# %%
query_str = "According to labor code tell me about DOLISA ?"
response = query_engine.query(query_str)
# Out:
# Llama.generate: prefix-match hit
# WARNING:llama_index.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# Llama.generate: prefix-match hit

# %%
response

# %%
print(response)
# Out:
#  DOLISA, which stands for "Department of Labor, Invalids and Social Affairs," is an organization that is responsible for various tasks related to labor and employment issues in Vietnam. It is a subset of the Ministry of Labor, Invalids and Social Affairs (MOLISA).
#
# According to the given information, DOLISA can confirm work permit exemptions for employers and expatriates. Employers must file an application with DOLISA to confirm work permit exemptions for their expatriate employees. Additionally, expatriates must meet certain conditions, such as being in good health, of full age (18 years or older), not being subject to prosecution, and working as a manager/general director or chief representative, expert, or technician, among other things.
#
# Furthermore, DOLISA is the organization that issues legal documents related to labor and employment. It also ensures compliance with national policies on employment and provides guidance concerning these policies.
#
# It's important to note that while DOLISA plays a significant role in labor and employment matters, it operates under the People’s Committee, which determines sufficient demand for expatriate employment and provides regulations on the labor

# %%
index.storage_context.persist(persist_dir = './content/graph_chatbot') #save index

# %%
# !zip -r /content/content/graph_chatbot.zip /content/content/graph_chatbot
# Out:
#   adding: content/content/graph_chatbot/ (stored 0%)
#   adding: content/content/graph_chatbot/default__vector_store.json (deflated 19%)
#   adding: content/content/graph_chatbot/index_store.json (deflated 84%)
#   adding: content/content/graph_chatbot/docstore.json (deflated 88%)
#   adding: content/content/graph_chatbot/image__vector_store.json (deflated 19%)

# %%
#%rm -rf content

# %%
storage_graph = StorageContext.from_defaults(persist_dir = '/content/graph_chatbot',graph_store = graph_store)

# %%
kg_index = load_index_from_storage(
    storage_context = storage_graph,
    service_context = service_context,
    max_triplets_per_chunk = 10,
    llm = llm
)

# %%
kg_query_engine = kg_index.as_query_engine(
    include_text=False,
    response_mode="tree_summarize", #test response !!!
    #embedding_mode="hybrid", #
    similarity_top_k=5,
)

# %%
query_str = "According to labor code tell me about DOLISA ?"
response = kg_query_engine.query(query_str)
# Out:
# WARNING:llama_index.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...

# %%
print(response)
# Out:
# DOLISA is an entity that is mentioned in the labor code. It is regulated by the labor code and is further elaborated upon in other sources. The labor code provides for certain rights and obligations for DOLISA, which may include topics such as employment relationships, payment obligations, and working conditions. The labor code may also specify the duration and number of occurrences of certain provisions that apply to DOLISA.

# %%
from llama_index.evaluation import DatasetGenerator

import random
random.seed(42)
question_dataset = []

data_generator = DatasetGenerator.from_documents(documents)
generated_questions = data_generator.generate_questions_from_nodes()
print(f"Generated {len(generated_questions)} questions.")

# randomly pick 30 questions
generated_questions = random.sample(generated_questions, 30)
question_dataset.extend(generated_questions)
# Out:
# WARNING:llama_index.service_context:chunk_size_limit is deprecated, please specify chunk_size instead
# chunk_size_limit is deprecated, please specify chunk_size instead
# chunk_size_limit is deprecated, please specify chunk_size instead
# /usr/local/lib/python3.10/dist-packages/llama_index/evaluation/dataset_generation.py:184: DeprecationWarning: Call to deprecated class DatasetGenerator. (Deprecated in favor of `RagDatasetGenerator` which should be used instead.)
#   return cls(

# %%
from llama_index.evaluation import FaithfulnessEvaluator, RelevancyEvaluator

faith = FaithfulnessEvaluator(service_context = service_context)
relevancy = RelevancyEvaluator(service_context = service_context)

# %%
from llama_index import Response
import pandas as pd

def display_eval_df(query: str, response: Response, eval_result: str) -> None:
    if response.source_nodes == []:
        print("no response!")
        return
    eval_df = pd.DataFrame(
        {
            "Query": query,
            "Response": str(response),
            "Source": response.source_nodes[0].node.text[:500] + "...",
            "Evaluation Result": "Pass" if eval_result.passing else "Fail",
        },
        index = [0]
    )

    eval_df = eval_df.style.set_properties(
        **{
            "inline-size": "600px",
            "overflow-wrap": "break-word",
        },
        subset=["Response", "Source"]
    )
    display(eval_df)

# %%
for query in question_dataset:
    response = metadata_query_engine.query(query)
    eval_result = faithfulness_gpt4.evaluate_response(response=response)
    display_eval_df(query, response, eval_result)

# %%
from llama_index.memory import ChatMemoryBuffer

memory = ChatMemoryBuffer.from_defaults(token_limit=1500)
# chat_engine = ReActAgent.from_tools(
#     query_engine_tools, llm=llm, memory=memory, verbose=True
# )

chat_engine = kg_index.as_chat_engine(
    chat_mode="react",
    memory=memory,
    verbose=True,
)

# %%
response = chat_engine.chat("According to labor code tell me about DOLISA")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Thought: I need to use a tool to help me answer the question.
# Action: query_engine_tool
# Action Input: {'input': 'What is DOLISA?'}
# Extracted keywords: ['DOLISA']
# WARNING:llama_index.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# KG context:
# The following are knowledge sequence in max depth 2 in the form of directed graph like:
# `subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...`
# ['LOCATED_IN', 'city or province']
# ['IS_RESPONSIBLE_FOR', 'administering employment issues']
# ['RESPONSIBLE_FOR', 'reviewing work permit applications for expatriates']
# ['IS_A_SUBSET_OF', 'MOLISA']
# ['IS_A_SUBSET_OF', 'MOLISA', 'RELATED_TO', 'labor and employment issues']
# ['IS_A_SUBSET_OF', 'MOLISA', 'CAN_ISSUE', 'legal documents related to labor and employment']
# ['IS_A_SUBSET_OF', 'MOLISA', 'CAN_ISSUE', 'legal documents']
# ['IS_A_SUBSET_OF', 'MOLISA', 'LOCATED_IN', 'labor and employment sector']
# ['IS_A_SUBSET_OF', 'MOLISA', 'LOCATED_IN', 'Vietnam']
# ['IS_A_SUBSET_OF', 'MOLISA', 'IS_RESPONSIBLE_FOR', 'labor_administration']
# ['IS_A_SUBSET_OF', 'MOLISA', 'IS_RESPONSIBLE_FOR', 'employment_and_occupational_safety_and_health']
# ['IS_A_SUBSET_OF', 'MOLISA', 'HAS_POWER_TO', 'implement_national_policies_on_employment']
# ['IS_A_SUBSET_OF', 'MOLISA', 'PROVIDES', 'guidance_concerning_employment_policies']
# ['IS_A_SUBSET_OF', 'MOLISA', 'ENSURES', 'compliance']
# ['IS_A_SUBSET_OF', 'MOLISA', 'IS_AN_ORGANIZATION', 'Vietnamese government agency']
# ['IS_A_SUBSET_OF', 'MOLISA', 'IS_AN_ORGANIZATION', 'Vietnamese Labor Relations Board']
# ['IS_A_SUBSET_OF', 'MOLISA', 'RESPONSIBLE_FOR', 'labor and employment issues']
# ['IS_A_SUBSET_OF', 'MOLISA', 'RESPONSIBLE_FOR', 'drafting and issuing legal documents']
# ['IS_A_SUBSET_OF', 'MOLISA', 'HAS_THE_POWER_TO_IMPLEMENT', 'national policies on employment']
# ['IS_A_SUBSET_OF', 'MOLISA', 'PROVIDES_GUIDANCE_CONCERNING', 'national policies on employment']
# ['IS_A_SUBSET_OF', 'MOLISA', 'ENSURES_COMPLIANCE_WITH', 'national policies on employment']
# ['IS_A_SUBSET_OF', 'MOLISA', 'IS', 'organization']
# ['IS_UNDER', 'People’s Committee']
# ['IS_UNDER', 'People’s Committee', 'PROVIDES_AFFIRMATION_FOR', 'employer']
# ['IS_UNDER', 'People’s Committee', 'DETERMINES_SUFFICIENT_DEMAND_FOR', 'expatriate employment']
# ['IS_UNDER', 'People’s Committee', 'PROVIDES_REGULATIONS_ON', 'labor code']
# ['ADMINISTERS_EMPLOYMENT_ISSUES_IN', 'province or centrally-run city']
# ['IS_LOCATED_IN', 'a province or centrally-run city']
# ['REVIEWS_APPLICATIONS_FOR', 'work permits for expatriates']
# ['REPORTS_ON', 'termination of employment']
# ['ADMINISTERS_EMPLOYMENT_ISSUES_WITHIN', 'locality']
# ['REVIEWS_APPLICATIONS_FOR_WORK_PERMITS_FOR', 'expatriates']
# ['ADMINISTERS', 'employment issues']
# ['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers']
# ['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'MUST_FILE_APPLICATION_WITH', 'DOLISA']
# ['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'TOCONTRIBUTEORPAY', 'socialInsurance']
# ['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'TOCONTRIBUTEORPAY', 'healthInsurance']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'IS', 'foreigner']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'CAN_WORK_AS', 'manager/general director or Chief Representative or expert or technician']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'MUST_MEET_CONDITIONS', 'work permit']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'IN_GOOD_HEALTH', 'null']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'FULL_AGE', '18']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'NOT_SUBJECT', 'prosecution']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'manager or GD']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'CR']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'expert or technician']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'CAN_BE_EXEMPTED_FROM_WORK_PERMIT', 'given employer application and conditions']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'REQUIRES_WORK_PERMIT_FOR', 'employment']
# ['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'DOCUMENTS_REQUIRED_FOR', 'work permit application']
# Observation: DOLISA is an entity that is responsible for various aspects related to employment. It oversees and regulates employment matters, ensures compliance with labor laws, manages work permits for expatriates, and provides support in cases of employment termination.
# Thought: I can answer without using any more tools.
# Answer: DOLISA stands for Department of Labor, Invalids and Social Affairs. It is an entity responsible for various aspects related to employment in Vietnam. DOLISA oversees and regulates employment matters, ensures compliance with labor laws, manages work permits for expatriates, and provides support in cases of employment termination.
# <b>DOLISA stands for Department of Labor, Invalids and Social Affairs. It is an entity responsible for various aspects related to employment in Vietnam. DOLISA oversees and regulates employment matters, ensures compliance with labor laws, manages work permits for expatriates, and provides support in cases of employment termination.</b>

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='a5da5040-f74e-4aec-95c4-7854da9a0699', embedding=None, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1f147982-13f8-4471-b50c-c159fa11c6ae', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='ddbea3a6bb74c7b445808c7bc7de8eea5afa10f87c3b11f8dd1da201469eda5d'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='89ad4675-0e4f-46d7-b87c-042a02832b9b', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='0b76029669022986b5ce772e04a8e7b3f5f8789505ccc3d9ed18ff48445eb05f'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='f6f82aad-62f5-4150-9eaa-c250f508b727', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='b5e0938b31d92714c01ab4c3d52d4fc51d72e4e378603df8c5cf0a4bb8cd3ecc')}, hash='68de295272db6ad1638e04a4810e27087751f64a4131210a969f6bd828ba8b97', text='It administers employment issues w ithin its locality. A company is subject to the \nDOLISA of the province o r city in which it is located. A company’s Internal Labor Ru les are \nregistered with DOLISA . DOLISA reviews applications for work permits for expatria tes and \nreports on termination of employment, as discussed throughout this Manual.  \n \n3.3 The Vietnam General Confederation of Labor  \n \nThe Vietnam General Confederation of Labor, in conjunction with trade unions at all levels, \nsupervises compliance with labor laws.  \n \nTrade unions represent collective labor in Vietnam.', start_char_idx=215, end_char_idx=803, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1000.0),
#  NodeWithScore(node=TextNode(id_='3dc9803d-82ee-4e4d-93ed-8b90d3222c62', embedding=None, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1f147982-13f8-4471-b50c-c159fa11c6ae', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='ddbea3a6bb74c7b445808c7bc7de8eea5afa10f87c3b11f8dd1da201469eda5d'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='f6f82aad-62f5-4150-9eaa-c250f508b727', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='b5e0938b31d92714c01ab4c3d52d4fc51d72e4e378603df8c5cf0a4bb8cd3ecc'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2da64e7a-8bae-4642-969e-d6681f29708a', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a8e4a786087274cf45646c4634b20f265cb5799c539a513c218a17811b4c969e')}, hash='318031cf0a1ba7a1efefd2639019c6a7fdbec12efb87e079caad141fcfb9801f', text='DOLISA reviews applications for work permits for expatria tes and \nreports on termination of employment, as discussed throughout this Manual.  \n \n3.3 The Vietnam General Confederation of Labor  \n \nThe Vietnam General Confederation of Labor, in conjunction with trade unions at all levels, \nsupervises compliance with labor laws.  \n \nTrade unions represent collective labor in Vietnam.  In addition to the trade union, employees \nhave the right to establish their  own representative  organization  which is not a member of the \nVietnam General Confederation of Labor .  The Government will issue a new decree to provide \nguidance on procedures to establish employees’ representativ es organization .', start_char_idx=419, end_char_idx=1118, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1000.0),
#  NodeWithScore(node=TextNode(id_='89ad4675-0e4f-46d7-b87c-042a02832b9b', embedding=None, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1f147982-13f8-4471-b50c-c159fa11c6ae', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='ddbea3a6bb74c7b445808c7bc7de8eea5afa10f87c3b11f8dd1da201469eda5d'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='f5e4faf2-326e-4428-939e-ae1fcd38ea37', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '2', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='b2cc97493e8845139975e6362c9a857ca73ad881f0725a4607a8b1af4951a263'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='a5da5040-f74e-4aec-95c4-7854da9a0699', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='3b72c0ccccff58a4d47e9179619fd4a28f0b781a8b5804e033b77e72aa51fd36')}, hash='0ce260a95abfd05c8290acd45d3e9e03917218b7b8450184e219aaa4150a0eea', text='It administers employment issues w ithin its locality. A company is subject to the \nDOLISA of the province o r city in which it is located. A company’s Internal Labor Ru les are \nregistered with DOLISA . DOLISA reviews applications for work permits for expatria tes and \nreports on termination of employment, as discussed throughout this Manual.  \n \n3.3 The Vietnam General Confederation of Labor  \n \nThe Vietnam General Confederation of Labor, in conjunction with trade unions at all levels, \nsupervises compliance with labor laws.', start_char_idx=215, end_char_idx=747, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1000.0),
#  NodeWithScore(node=TextNode(id_='51651103-f50c-4b88-9756-4df2ec480744', embedding=None, metadata={'kg_rel_texts': ["['LOCATED_IN', 'city or province']", "['IS_RESPONSIBLE_FOR', 'administering employment issues']", "['RESPONSIBLE_FOR', 'reviewing work permit applications for expatriates']", "['IS_A_SUBSET_OF', 'MOLISA']", "['IS_A_SUBSET_OF', 'MOLISA', 'RELATED_TO', 'labor and employment issues']", "['IS_A_SUBSET_OF', 'MOLISA', 'CAN_ISSUE', 'legal documents related to labor and employment']", "['IS_A_SUBSET_OF', 'MOLISA', 'CAN_ISSUE', 'legal documents']", "['IS_A_SUBSET_OF', 'MOLISA', 'LOCATED_IN', 'labor and employment sector']", "['IS_A_SUBSET_OF', 'MOLISA', 'LOCATED_IN', 'Vietnam']", "['IS_A_SUBSET_OF', 'MOLISA', 'IS_RESPONSIBLE_FOR', 'labor_administration']", "['IS_A_SUBSET_OF', 'MOLISA', 'IS_RESPONSIBLE_FOR', 'employment_and_occupational_safety_and_health']", "['IS_A_SUBSET_OF', 'MOLISA', 'HAS_POWER_TO', 'implement_national_policies_on_employment']", "['IS_A_SUBSET_OF', 'MOLISA', 'PROVIDES', 'guidance_concerning_employment_policies']", "['IS_A_SUBSET_OF', 'MOLISA', 'ENSURES', 'compliance']", "['IS_A_SUBSET_OF', 'MOLISA', 'IS_AN_ORGANIZATION', 'Vietnamese government agency']", "['IS_A_SUBSET_OF', 'MOLISA', 'IS_AN_ORGANIZATION', 'Vietnamese Labor Relations Board']", "['IS_A_SUBSET_OF', 'MOLISA', 'RESPONSIBLE_FOR', 'labor and employment issues']", "['IS_A_SUBSET_OF', 'MOLISA', 'RESPONSIBLE_FOR', 'drafting and issuing legal documents']", "['IS_A_SUBSET_OF', 'MOLISA', 'HAS_THE_POWER_TO_IMPLEMENT', 'national policies on employment']", "['IS_A_SUBSET_OF', 'MOLISA', 'PROVIDES_GUIDANCE_CONCERNING', 'national policies on employment']", "['IS_A_SUBSET_OF', 'MOLISA', 'ENSURES_COMPLIANCE_WITH', 'national policies on employment']", "['IS_A_SUBSET_OF', 'MOLISA', 'IS', 'organization']", "['IS_UNDER', 'People’s Committee']", "['IS_UNDER', 'People’s Committee', 'PROVIDES_AFFIRMATION_FOR', 'employer']", "['IS_UNDER', 'People’s Committee', 'DETERMINES_SUFFICIENT_DEMAND_FOR', 'expatriate employment']", "['IS_UNDER', 'People’s Committee', 'PROVIDES_REGULATIONS_ON', 'labor code']", "['ADMINISTERS_EMPLOYMENT_ISSUES_IN', 'province or centrally-run city']", "['IS_LOCATED_IN', 'a province or centrally-run city']", "['REVIEWS_APPLICATIONS_FOR', 'work permits for expatriates']", "['REPORTS_ON', 'termination of employment']", "['ADMINISTERS_EMPLOYMENT_ISSUES_WITHIN', 'locality']", "['REVIEWS_APPLICATIONS_FOR_WORK_PERMITS_FOR', 'expatriates']", "['ADMINISTERS', 'employment issues']", "['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers']", "['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'MUST_FILE_APPLICATION_WITH', 'DOLISA']", "['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'TOCONTRIBUTEORPAY', 'socialInsurance']", "['CAN_CONFIRM_WORK_PERMIT_EXEMPTION_FOR', 'employers', 'TOCONTRIBUTEORPAY', 'healthInsurance']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'IS', 'foreigner']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'CAN_WORK_AS', 'manager/general director or Chief Representative or expert or technician']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'MUST_MEET_CONDITIONS', 'work permit']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'IN_GOOD_HEALTH', 'null']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'FULL_AGE', '18']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'NOT_SUBJECT', 'prosecution']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'manager or GD']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'CR']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'WORK_AS', 'expert or technician']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'CAN_BE_EXEMPTED_FROM_WORK_PERMIT', 'given employer application and conditions']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'REQUIRES_WORK_PERMIT_FOR', 'employment']", "['CANCONFIRMEXEMPTIONFOR', 'expatriate', 'DOCUMENTS_REQUIRED_FOR', 'work permit application']"], 'kg_rel_map': {'DOLISA': [['LOCATED_IN', 'city or province'], ['IS_RESPONSIBLE_FOR', 'administ ...

# %%
from llama_index.evaluation import RelevancyEvaluator
import nest_asyncio
nest_asyncio.apply()
evaluator = RelevancyEvaluator(service_context=service_context)
response_str = response.response
for source_node in response.source_nodes:
    eval_result = evaluator.evaluate(
        query="According to labor code tell me about DOLISA",
        response=response_str,
        contexts=[source_node.get_content()],
    )
    print(str(eval_result.passing))
# Out:
# True
# True
# /usr/local/lib/python3.10/dist-packages/debugpy/_vendored/pydevd/_pydevd_bundle/_debug_adapter/pydevd_schema.py:13662: RuntimeWarning: coroutine 'RelevancyEvaluator.aevaluate' was never awaited
#   dct['source'] = source.to_dict(update_ids_to_dap=update_ids_to_dap)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# True
# True

# %%
response = chat_engine.chat("Arcording to labor code tell me employees who work overtime will be paid how much ?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Thought: I can use the query_engine_tool to find the information about overtime pay in the labor code.
# Action: query_engine_tool
# Action Input: {'input': 'overtime pay in labor code'}
# Extracted keywords: ['labor', 'overtime pay', 'code', 'pay', 'labor code', 'overtime']
# WARNING:llama_index.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# Index was not constructed with embeddings, skipping embedding usage...
# Observation: The Labor Code provides regulations on overtime pay. Employees who work overtime are entitled to receive at least 150% of their actually paid salary for a normal work day. For a normal weekly day off, such as weekends, they should receive at least 200% of their actually paid salary. On public holidays or during fully paid leave days, employees should receive at least 300% of their actually paid salary, in addition to their normal salary on these days. Additionally, employees who work at night are entitled to an additional payment of 30% of their normal base salary for each work day.
# Thought: I have found the information about overtime pay in the labor code.
# Answer: According to the labor code, employees who work overtime will be paid at least 150% of their actually paid salary for a normal work day. On a normal weekly day off, such as weekends, they should receive at least 200% of their actually paid salary. On public holidays or during fully paid leave days, employees should receive at least 300% of their actually paid salary, in addition to their normal salary on these days. Additionally, employees who work at night are entitled to an additional payment of 30% of their normal base salary for each work day.
# <b>According to the labor code, employees who work overtime will be paid at least 150% of their actually paid salary for a normal work day. On a normal weekly day off, such as weekends, they should receive at least 200% of their actually paid salary. On public holidays or during fully paid leave days, employees should receive at least 300% of their actually paid salary, in addition to their normal salary on these days. Additionally, employees who work at night are entitled to an additional payment of 30% of their normal base salary for each work day.</b>

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='3175b802-552a-4c8d-9650-4c3be4fd0d0d', embedding=None, metadata={'page_label': '6', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='08779e89-f7ec-4e3d-900f-677920a2912e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '6', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='562f80129584c73a1527d19da6b9f060e77976c1e66af790c65ccc1410f83bf8'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='1d5e26fd-e151-4df1-8b4a-539e602ecce0', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '6', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='2a4013a6023c084c75a953849049ccbcb75358d88bdcca04569badda3b43ff82'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='8ec1aa5e-eeab-48f8-9a61-9deeb9dfe6c6', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8ed944941306bb3321c605789bbbde22625790f22572a8c9351dee09f753c8eb')}, hash='f31ae6fa338d0c12a7b51cb12561eb6a7fe6147e8ba41161e6da63682f410afb', text='The work permit can be renewed  one time only  \nfor a two year term .  For renewal,  some documents and procedures are waived. A new \napplication must be filed after the renewed work permit expires . \n \nPrior to obtaining a work permit for  an expatriate, the employer must obtain an affirmation \nfrom the People’s Committee that there is sufficient demand which necessitat es recruit ment of  \nan exp atriate . Some exemptions can be applied.  \n \n6. Probation  \n \nRegulations on probation are provided in Article 24 of the Labor Code . \n \nAn employer and an employee may enter into an agreement on probation : \n \nIf the employee is recruited for a managerial position  (eg,', start_char_idx=624, end_char_idx=1298, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1000.0),
#  NodeWithScore(node=TextNode(id_='684c42ae-0f75-4d64-891a-4ec39227e873', embedding=None, metadata={'page_label': '9', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='3c89ed47-5752-41ab-9ecf-ad6480a54d2c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '9', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='eacf3c3e849ec5d7a130e7692239e9257178c1b7a4994e302d9a4a1bee8ec1d4'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='81fc2832-2793-42b5-b62d-1e269f1a1b45', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '9', 'file_name': 'Employment-Manual-January-2023-trang-1.pdf'}, hash='b1e01e86628d0e432e521422bad2759a077a4245f8debdc4048ebde4733bbd37'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='32d1ed86-16be-40d7-889d-56ebad20465b', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='66ffc7e143675d40cbf44214db908407969c93b4b7c9d9bc480d76249da64459')}, hash='3251e7e1721cfda1be6560c12a1bb362238096c94f7e6487ba44483bfeeb0615', text='8.3 Payment for overtime and night work  \n \nEmployees who work overtime will be paid12: \n \n• At least 150% of actually paid salary for a normal work day;  \n• At least 200% of actually paid  salary for a normal weekly day off (eg, weekends);  \n• At least 300% of actually paid salary for a pub lic holiday or during fully paid leave days , \nplus her normal salary on these  days. \n \nEmployees who work at night are entitled to an additional payment of 30% of the normal base \nsalary for each work day.', start_char_idx=1471, end_char_idx=1971, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=1000.0)]
